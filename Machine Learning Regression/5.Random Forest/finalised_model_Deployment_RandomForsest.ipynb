# %%
import pickle

# %%
loaded_model=pickle.load(open("Finalised_Random_Forest.sav", 'rb'))  
result=loaded_model.predict([[1234,25,887,True,False]])
# Out:
# C:\Users\ragav\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([47799.7606])
