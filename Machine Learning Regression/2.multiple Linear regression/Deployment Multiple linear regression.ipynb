# %%
import pickle  
filename="Finalised_model_multiple_linear.sav"

# %%
loaded_model=pickle.load(open("Finalised_model_multiple_linear.sav", 'rb'))  
result=loaded_model.predict([[1352,179,22,0,234]])
# Out:
# C:\Users\ragav\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[114802.27463446]])
